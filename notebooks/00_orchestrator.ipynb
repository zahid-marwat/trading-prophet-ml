# %% [markdown]
# # Orchestrator Pipeline
#
# This notebook runs the end-to-end pipeline (fetch → features → patterns → signals → backtest) and returns key metrics.
#
# **Not financial advice. Use at your own risk.**

# %%
from src.pipeline import run_quick_analysis

result = run_quick_analysis(asset="AAPL", timeframe="1d", period="1y")
result
